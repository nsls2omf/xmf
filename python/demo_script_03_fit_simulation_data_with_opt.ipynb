# %% [markdown]
# # Demo script_03 fit simulation data with opt

# %%
import numpy as np
import xmf

# %%
## 1. Lateral coordinates

x_range = 200e-3 
y_range = 20e-3 
x_num = 201 
y_num = 21 

x1d = np.linspace(-x_range/2, x_range/2, x_num) 
y1d = np.linspace(-y_range/2, y_range/2, y_num) 
x2d, y2d = np.meshgrid(x1d, y1d)

abs_p = 30 
abs_q = 0.3
theta = 30e-3 

abs_q_t = 0.3
abs_q_s = 0.6

x_i = -1e-3 
y_i = -2e-4 
z_i = 3e-7 
alpha = 2e-6 
beta = 1e-5 
gamma = 0.5e-3 

true_params_dict = {
    'p': abs_p,
    'q': abs_q,
    'theta': theta,
    'x_i': x_i,
    'y_i': y_i,
    'z_i': z_i,
    'alpha': alpha,
    'beta': beta,
    'gamma': gamma
}

height_measurement_noise_std = 0.5e-9
slope_measurement_noise_std = 100e-9

input_params_dict = {
    'p': abs_p,
    'q': abs_q,
    'theta': theta
}

input_scd_params_dict = {
    'p': abs_p,
    'q': abs_q_t,
    'theta': theta
}

input_tcd_params_dict = {
    'p': abs_p,
    'q': abs_q_s,
    'theta': theta
}

opt_dict = {
    'p': False,
    'q': False,
    'theta': False
}

# %%
## 2.1. Convex Ellipsoid (CVXE)

z2d = xmf.generate_2d_curved_surface_height(xmf.standard_convex_ellipsoid_height, x2d, y2d, abs_p, abs_q, theta, x_i, y_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_convex_ellipsoid_height(x2d, y2d, z2d_measured, input_params_dict, opt_dict) 
xmf.fig_show_2d_fitting_map(x2d, y2d, z2d_measured, z2d_fit, z2d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Convex Ellipsoid')

# %%
## 2.2. Concave Ellipsoid (CCVE)

z2d = xmf.generate_2d_curved_surface_height(xmf.standard_concave_ellipsoid_height, x2d, y2d, abs_p, abs_q, theta, x_i, y_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_concave_ellipsoid_height(x2d, y2d, z2d_measured, input_params_dict, opt_dict) 
xmf.fig_show_2d_fitting_map(x2d, y2d, z2d_measured, z2d_fit, z2d_res, init_params_dict, opt_params_dict, opt_params_ci_dict,'Concave Ellipsoid')

# %%
## 3.1. Convex Elliptic Cylinder (CVXEC)

z2d = xmf.generate_2d_cylinder_height(xmf.standard_convex_elliptic_cylinder_height, x2d, y2d, abs_p, abs_q, theta, x_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_convex_elliptic_cylinder_height(x2d, y2d, z2d_measured, input_params_dict, opt_dict) 
xmf.fig_show_2d_fitting_map(x2d, y2d, z2d_measured, z2d_fit, z2d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Convex Elliptic Cylinder') 

z1d = xmf.generate_1d_height(xmf.standard_convex_elliptic_cylinder_height, x1d, abs_p, abs_q, theta, x_i, z_i, beta) 
z1d_measured = z1d + np.random.randn(z1d.shape[0])*height_measurement_noise_std 
z1d_res, z1d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_convex_ellipse_height(x1d, z1d_measured, input_params_dict, opt_dict) 
xmf.fig_show_1d_fitting_height(x1d, z1d_measured, z1d_fit, z1d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Convex Elliptic Cylinder') 

sx1d = xmf.generate_1d_slope(xmf.standard_convex_elliptic_cylinder_xslope, x1d, abs_p, abs_q, theta, x_i, beta) 
sx1d_measured = sx1d + np.random.randn(sx1d.shape[0])*slope_measurement_noise_std 
sx1d_res, sx1d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_convex_ellipse_slope(x1d, sx1d_measured, input_params_dict, opt_dict) 
xmf.fig_show_1d_fitting_slope(x1d, sx1d_measured, sx1d_fit, sx1d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Convex Elliptic Cylinder')

# %%
## 3.2. Concave Elliptic Cylinder (CCVEC)

z2d = xmf.generate_2d_cylinder_height(xmf.standard_concave_elliptic_cylinder_height, x2d, y2d, abs_p, abs_q, theta, x_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_concave_elliptic_cylinder_height(x2d, y2d, z2d_measured, input_params_dict, opt_dict) 
xmf.fig_show_2d_fitting_map(x2d, y2d, z2d_measured, z2d_fit, z2d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Concave Elliptic Cylinder') 

z1d = xmf.generate_1d_height(xmf.standard_concave_elliptic_cylinder_height, x1d, abs_p, abs_q, theta, x_i, z_i, beta) 
z1d_measured = z1d + np.random.randn(z1d.shape[0])*height_measurement_noise_std 
z1d_res, z1d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_concave_ellipse_height(x1d, z1d_measured, input_params_dict, opt_dict) 
xmf.fig_show_1d_fitting_height(x1d, z1d_measured, z1d_fit, z1d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Concave Elliptic Cylinder') 

sx1d = xmf.generate_1d_slope(xmf.standard_concave_elliptic_cylinder_xslope, x1d, abs_p, abs_q, theta, x_i, beta) 
sx1d_measured = sx1d + np.random.randn(sx1d.shape[0])*slope_measurement_noise_std 
sx1d_res, sx1d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_concave_ellipse_slope(x1d, sx1d_measured, input_params_dict, opt_dict) 
xmf.fig_show_1d_fitting_slope(x1d, sx1d_measured, sx1d_fit, sx1d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Concave Elliptic Cylinder')

# %%
## 6.1. Convex Hyperboloid (CVXH)

z2d = xmf.generate_2d_curved_surface_height(xmf.standard_convex_hyperboloid_height, x2d, y2d, abs_p, abs_q, theta, x_i, y_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_convex_hyperboloid_height(x2d, y2d, z2d_measured, input_params_dict, opt_dict) 
xmf.fig_show_2d_fitting_map(x2d, y2d, z2d_measured, z2d_fit, z2d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Convex Hyperboloid')

# %%
## 6.2. Concave Hyperboloid (CCVH)

z2d = xmf.generate_2d_curved_surface_height(xmf.standard_concave_hyperboloid_height, x2d, y2d, abs_p, abs_q, theta, x_i, y_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_concave_hyperboloid_height(x2d, y2d, z2d_measured, input_params_dict, opt_dict) 
xmf.fig_show_2d_fitting_map(x2d, y2d, z2d_measured, z2d_fit, z2d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Concave Hyperboloid')

# %%
## 7.1. Convex Hyperbolic Cylinder (CVXHC)

z2d = xmf.generate_2d_cylinder_height(xmf.standard_convex_hyperbolic_cylinder_height, x2d, y2d, abs_p, abs_q, theta, x_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_convex_hyperbolic_cylinder_height(x2d, y2d, z2d_measured, input_params_dict, opt_dict) 
xmf.fig_show_2d_fitting_map(x2d, y2d, z2d_measured, z2d_fit, z2d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Convex Hyperbolic Cylinder') 

z1d = xmf.generate_1d_height(xmf.standard_convex_hyperbolic_cylinder_height, x1d, abs_p, abs_q, theta, x_i, z_i, beta) 
z1d_measured = z1d + np.random.randn(z1d.shape[0])*height_measurement_noise_std 
z1d_res, z1d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_convex_hyperbola_height(x1d, z1d_measured, input_params_dict, opt_dict) 
xmf.fig_show_1d_fitting_height(x1d, z1d_measured, z1d_fit, z1d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Convex Hyperbolic Cylinder') 

sx1d = xmf.generate_1d_slope(xmf.standard_convex_hyperbolic_cylinder_xslope, x1d, abs_p, abs_q, theta, x_i, beta) 
sx1d_measured = sx1d + np.random.randn(sx1d.shape[0])*slope_measurement_noise_std 
sx1d_res, sx1d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_convex_hyperbola_slope(x1d, sx1d_measured, input_params_dict, opt_dict) 
xmf.fig_show_1d_fitting_slope(x1d, sx1d_measured, sx1d_fit, sx1d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Convex Hyperbolic Cylinder')

# %%
## 7.2. Concave Hyperbolic Cylinder (CCVHC)

z2d = xmf.generate_2d_cylinder_height(xmf.standard_concave_hyperbolic_cylinder_height, x2d, y2d, abs_p, abs_q, theta, x_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_concave_hyperbolic_cylinder_height(x2d, y2d, z2d_measured, input_params_dict, opt_dict) 
xmf.fig_show_2d_fitting_map(x2d, y2d, z2d_measured, z2d_fit, z2d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Concave Hyperbolic Cylinder') 

z1d = xmf.generate_1d_height(xmf.standard_concave_hyperbolic_cylinder_height, x1d, abs_p, abs_q, theta, x_i, z_i, beta) 
z1d_measured = z1d + np.random.randn(z1d.shape[0])*height_measurement_noise_std 
z1d_res, z1d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_concave_hyperbola_height(x1d, z1d_measured, input_params_dict, opt_dict) 
xmf.fig_show_1d_fitting_height(x1d, z1d_measured, z1d_fit, z1d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Concave Hyperbolic Cylinder') 

sx1d = xmf.generate_1d_slope(xmf.standard_concave_hyperbolic_cylinder_xslope, x1d, abs_p, abs_q, theta, x_i, beta) 
sx1d_measured = sx1d + np.random.randn(sx1d.shape[0])*slope_measurement_noise_std 
sx1d_res, sx1d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_concave_hyperbola_slope(x1d, sx1d_measured, input_params_dict, opt_dict) 
xmf.fig_show_1d_fitting_slope(x1d, sx1d_measured, sx1d_fit, sx1d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Concave Hyperbolic Cylinder')

# %%
# 8.1. Sagittal Collimating Diaboloid (SCD)

true_scd_params_dict = {
    'p': abs_p,
    'q': abs_q_t,
    'theta': theta,
    'x_i': x_i,
    'y_i': y_i,
    'z_i': z_i,
    'alpha': alpha,
    'beta': beta,
    'gamma': gamma
}

z2d = xmf.generate_2d_curved_surface_height(xmf.standard_sag_col_diaboloid_height, x2d, y2d, abs_p, abs_q_t, theta, x_i, y_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_sag_col_diaboloid_height(x2d, y2d, z2d_measured, input_scd_params_dict, opt_dict) 
xmf.fig_show_2d_fitting_map(x2d, y2d, z2d_measured, z2d_fit, z2d_res, init_params_dict, opt_params_dict, opt_params_ci_dict, 'Sagittal Collimating Diaboloid')

# %%
# 8.2. Tangential Collimating Diaboloid (TCD)

true_tcd_params_dict = {
    'p': abs_p,
    'q': abs_q_s,
    'theta': theta,
    'x_i': x_i,
    'y_i': y_i,
    'z_i': z_i,
    'alpha': alpha,
    'beta': beta,
    'gamma': gamma
}

# 8.2.1. Tangential Collimating Diaboloid (TCD) without considering gamma

opt_dict = {
    'p': False,
    'q': False,
    'theta': False,
    'y_i': True,
    'gamma': False
}

z2d = xmf.generate_2d_curved_surface_height(xmf.standard_tan_col_diaboloid_height, x2d, y2d, abs_p, abs_q_s, theta, x_i, y_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res_wo_gamma, z2d_fit_wo_gamma, opt_params_dict_wo_gamma, opt_params_ci_dict_wo_gamma, init_params_dict_wo_gamma = xmf.fit_tan_col_diaboloid_height(x2d, y2d, z2d_measured, input_tcd_params_dict, opt_dict) 

# 8.2.2. Tangential Collimating Diaboloid (TCD) 

opt_dict = {
    'p': False,
    'q': False,
    'theta': False,
    'y_i': True,
    'gamma': True
}

z2d = xmf.generate_2d_curved_surface_height(xmf.standard_tan_col_diaboloid_height, x2d, y2d, abs_p, abs_q_s, theta, x_i, y_i, z_i, alpha, beta, gamma) 
z2d_measured = z2d + np.random.randn(z2d.shape[0], z2d.shape[1])*height_measurement_noise_std 
z2d_res, z2d_fit, opt_params_dict, opt_params_ci_dict, init_params_dict = xmf.fit_tan_col_diaboloid_height(x2d, y2d, z2d_measured, input_tcd_params_dict, opt_dict) 

xmf.fig_show_2d_different_fitting_maps(x2d, y2d, z2d_measured, z2d_fit_wo_gamma, z2d_res_wo_gamma, z2d_fit, z2d_res, init_params_dict, opt_params_dict_wo_gamma, opt_params_ci_dict_wo_gamma, opt_params_dict, opt_params_ci_dict, 'Tangential Collimating Diaboloid')
